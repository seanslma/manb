# %%
import pandas as pd
import polars as pl

from pathlib import Path
from mapy.tst.dataframe import gen_rand_df

dir = Path.home().joinpath('dat')

# %%
df = gen_rand_df(
    nrow=100000,
    str_cols={
        'count': 3,
        'name': ['s1', 's2', 's3'],
        'str_len': [10, (1,15), (1,50)],
        'str_count': [1000, 500, 100],
    },
    ts_cols={
        'count': 2,
        'name': ['t1', 't2'],
        'start_date': ['2020-01-01', '2021-01-01'],
        'end_date': ['2021-01-01', '2022-01-01'],
        'freq': 's',
        },
    float_cols={
        'count': 3,
        'name': [f'f{i}' for i in range(1, 4)],
        'low': 0,
        'high': 1,
    },
)
df[:2]
# Out:
#            s1         s2                                                 s3  \
# 0  ihXEKLSbEj  lntW4mY3W                      YpRNBGYJl7ZGa4hgzEGH3y4vj0N9x
# 1  88imtIZD8v  lntW4mY3W  MY7kuDMi37BLiUCIYffDNvln8lY7b5XRaFIvlbnOr4sWwF...
#
#                    t1                  t2        f1        f2        f3
# 0 2020-01-01 00:00:00 2021-01-01 00:00:00  0.123671  0.514421  0.505556
# 1 2020-01-01 00:00:01 2021-01-01 00:00:01  0.641670  0.073488  0.067666

# %%
xl = pd.ExcelWriter(dir.joinpath('test_xl.xlsx'))
df.to_excel(xl, index=False)
xl.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 xl = pd.ExcelWriter(dir.joinpath('test_xl.xlsx'))
#       2 df.to_excel(xl, index=False)
# ----> 3 xl.save()
#
# AttributeError: 'OpenpyxlWriter' object has no attribute 'save'

# %%
df.to_excel(dir.joinpath('test_df.xlsx'), sheet_name='df', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.to_excel(dir.joinpath('test_df.xlsx'), sheet_name='df', index=False)
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/pandas/core/generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)
#    2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/pandas/io/formats/excel.py:962, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     959 finally:
#     960     # make sure to close opened file handles
#     961     if need_save:
# --> 962         writer.close()
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/pandas/io/excel/_base.py:1357, in ExcelWriter.close(self)
#    1355 def close(self) -> None:
#    1356     """synonym for save, to make it more file-like"""
# -> 1357     self._save()
#    1358     self._handles.close()
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/pandas/io/excel/_openpyxl.py:110, in OpenpyxlWriter._save(self)
#     106 def _save(self) -> None:
#     107     """
#     108     Save workbook to disk.
#     109     """
# --> 110     self.book.save(self._handles.handle)
#     111     if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     112         # truncate file to the written content
#     113         self._handles.handle.truncate()
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/openpyxl/workbook/workbook.py:386, in Workbook.save(self, filename)
#     384 if self.write_only and not self.worksheets:
#     385     self.create_sheet()
# --> 386 save_workbook(self, filename)
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/openpyxl/writer/excel.py:294, in save_workbook(workbook, filename)
#     292 workbook.properties.modified = datetime.datetime.now(tz=datetime.timezone.utc).replace(tzinfo=None)
#     293 writer = ExcelWriter(workbook, archive)
# --> 294 writer.save()
#     295 return True
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/openpyxl/writer/excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/openpyxl/writer/excel.py:77, in ExcelWriter.write_data(self)
#      74     custom_override = CustomOverride()
#      75     self.manifest.append(custom_override)
# ---> 77 self._write_worksheets()
#      78 self._write_chartsheets()
#      79 self._write_images()
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/openpyxl/writer/excel.py:215, in ExcelWriter._write_worksheets(self)
#     212 for idx, ws in enumerate(self.workbook.worksheets, 1):
#     214     ws._id = idx
# --> 215     self.write_worksheet(ws)
#     217     if ws._drawing:
#     218         self._write_drawing(ws._drawing)
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/openpyxl/writer/excel.py:200, in ExcelWriter.write_worksheet(self, ws)
#     198 else:
#     199     writer = WorksheetWriter(ws)
# --> 200     writer.write()
#     202 ws._rels = writer._rels
#     203 self._archive.write(writer.out, ws.path[1:])
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/openpyxl/worksheet/_writer.py:361, in openpyxl.worksheet._writer.WorksheetWriter.write()
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/openpyxl/worksheet/_writer.py:369, in openpyxl.worksheet._writer.WorksheetWriter.close()
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/openpyxl/worksheet/_writer.py:288, in get_stream()
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/openpyxl/worksheet/_writer.py:289, in openpyxl.worksheet._writer.WorksheetWriter.get_stream()
#
# File ~/mambaforge/envs/dev/lib/python3.10/contextlib.py:142, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     140 if typ is None:
#     141     try:
# --> 142         next(self.gen)
#     143     except StopIteration:
#     144         return False
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/et_xmlfile/xmlfile.py:50, in _FakeIncrementalFileWriter.element(self, tag, attrib, nsmap, **_extra)
#      48     self._top_element = parent
#      49 else:
# ---> 50     self._write_element(el)
#      51     self._top_element = None
#
# File ~/mambaforge/envs/dev/lib/python3.10/site-packages/et_xmlfile/xmlfile.py:77, in _FakeIncrementalFileWriter._write_element(self, element)
#      76 def _write_element(self, element):
# ---> 77     xml = tostring(element)
#      78     self._file.write(xml)
#
# File ~/mambaforge/envs/dev/lib/python3.10/xml/etree/ElementTree.py:1102, in tostring(element, encoding, method, xml_declaration, default_namespace, short_empty_elements)
#    1088 """Generate string representation of XML element.
#    1089
#    1090 All subelements are included.  If encoding is "unicode", a string
#    (...)
#    1099
#    1100 """
#    1101 stream = io.StringIO() if encoding == 'unicode' else io.BytesIO()
# -> 1102 ElementTree(element).write(stream, encoding,
#    1103                            xml_declaration=xml_declaration,
#    1104                            default_namespace=default_namespace,
#    1105                            method=method,
#    1106                            short_empty_elements=short_empty_elements)
#    1107 return stream.getvalue()
#
# File ~/mambaforge/envs/dev/lib/python3.10/xml/etree/ElementTree.py:743, in ElementTree.write(self, file_or_filename, encoding, xml_declaration, default_namespace, method, short_empty_elements)
#     741 qnames, namespaces = _namespaces(self._root, default_namespace)
#     742 serialize = _serialize[method]
# --> 743 serialize(write, self._root, qnames, namespaces,
#     744           short_empty_elements=short_empty_elements)
#
# File ~/mambaforge/envs/dev/lib/python3.10/xml/etree/ElementTree.py:906, in _serialize_xml(write, elem, qnames, namespaces, short_empty_elements, **kwargs)
#     904         write(_escape_cdata(text))
#     905     for e in elem:
# --> 906         _serialize_xml(write, e, qnames, None,
#     907                        short_empty_elements=short_empty_elements)
#     908     write("</" + tag + ">")
#     909 else:
#
# File ~/mambaforge/envs/dev/lib/python3.10/xml/etree/ElementTree.py:906, in _serialize_xml(write, elem, qnames, namespaces, short_empty_elements, **kwargs)
#     904         write(_escape_cdata(text))
#     905     for e in elem:
# --> 906         _serialize_xml(write, e, qnames, None,
#     907                        short_empty_elements=short_empty_elements)
#     908     write("</" + tag + ">")
#     909 else:
#
# File ~/mambaforge/envs/dev/lib/python3.10/xml/etree/ElementTree.py:906, in _serialize_xml(write, elem, qnames, namespaces, short_empty_elements, **kwargs)
#     904         write(_escape_cdata(text))
#     905     for e in elem:
# --> 906         _serialize_xml(write, e, qnames, None,
#     907                        short_empty_elements=short_empty_elements)
#     908     write("</" + tag + ">")
#     909 else:
#
# File ~/mambaforge/envs/dev/lib/python3.10/xml/etree/ElementTree.py:882, in _serialize_xml(write, elem, qnames, namespaces, short_empty_elements, **kwargs)
#     880 else:
#     881     write("<" + tag)
# --> 882     items = list(elem.items())
#     883     if items or namespaces:
#     884         if namespaces:
#
# KeyboardInterrupt:
